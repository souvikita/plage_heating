# %%
from iris_lmsalpy import extract_irisL2data as ei
from iris_lmsalpy import data2model_knnmultiline as d2m
from iris_lmsalpy import showIRIS
import os
import astropy.units as u
from astropy.io import ascii
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget
# Out:
# Reversing the order of the color table
#
# Color table CB-PiYG has been load.
#
#
# Color table CB-BuGn has been load.

# %%
path = '/Users/souvikb/various_analysis/iris2_p/l2_iris_data/Photospheric_imprints_IRIS_l2_data/2017_03_05/'
filename = os.path.join(path, 'iris_l2_20170305_164021_3620106076_raster_t000_r00000.fits')
data = ei.load(filename) 
data = ei.load(filename, window_info=['all'], radcal='CGS_NU')  ### All lines with calibration
data.quick_look()
# Out:
# Loading... /Users/souvikb/iris_lmsalpy/iris_lmsalpy/data/NIST_2783_2835_onlyobs.jbl.gz
# Reference time is 20170305_16402393 (index 0)
# Reference time is 20170305_16402393 (index 0)
# Reference time is 20170305_16402399 (index 0)
# Reference time is 20170305_16402399 (index 0)
# Calibrating data...
# Trying to load...  /Users/souvikb/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20191101.geny
# Reference time is 20170305_16402399 (index 0)
# Reference time is 20170305_16402399 (index 0)
# Calibrating data...
# Trying to load...  /Users/souvikb/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20191101.geny
# /Users/souvikb/miniforge3/envs/iris2_p_inv/lib/python3.11/site-packages/astropy/time/formats.py:1637: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   val1_uint32 = val1.view((np.uint32, val1.dtype.itemsize // 4))
# ...

# %%
# crop_wei4knn= [[50, 112, 1334.55, 100.0], 
# [140, 202, 1335.72, 100.0], 
# [244, 252, 2793.22, 0.0], 
# [313, 391, 2796.35, 1.0], 
# [441, 456, 2798.8, 2.5064793835947374], 
# [595, 673, 2803.53, 1.2113248371455154], 
# [743, 751, 2815.18, 2.0]]

crop_wei4knn= [[50, 112, 1334.55, 100.0], 
[140, 202, 1335.72, 100.0], 
[244, 252, 2793.22, 0.0], 
[313, 391, 2796.35, 1.0], 
[441, 456, 2798.8, 1], 
[595, 673, 2803.53, 1], 
[743, 751, 2815.18, 2.0]]


data, inv, model, chi2, wl, wlc, crop_wei4knn, info_var_inv_iri2p = d2m.invert(filename,output_dir=path,crop_wei4knn=crop_wei4knn)
# Out:
# Loading... /Users/souvikb/iris_lmsalpy/iris_lmsalpy/data/NIST_2783_2835_onlyobs.jbl.gz
# Reference time is 20170305_16402393 (index 0)
# Reference time is 20170305_16402393 (index 0)
# Calibrating data...
# Trying to load...  /Users/souvikb/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20191101.geny
# /Users/souvikb/miniforge3/envs/iris2_p_inv/lib/python3.11/site-packages/astropy/time/formats.py:1637: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   val1_uint32 = val1.view((np.uint32, val1.dtype.itemsize // 4))
# Trying to load...  /Users/souvikb/iris_lmsalpy/iris_lmsalpy/iris_response_files/iris_sra_c_20161022.geny
# 0 - C II 1336 - 1332.72817016 to 1337.5307702029015
# 1 - Fe XII 1349 - 1347.70709029 to 1350.822290317828
# 2 - O I 1356 - 1352.25009033 to 1356.6113703689591
# 3 - Si IV 1394 - 1390.92262787 to 1396.1123878695105
# ...

# %%
showIRIS.iris2(data, inv, model, chi2, wl, wlc, figsize=[10,8], logne=False)
# Out:
# [['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], ['I [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}$]', 'Inv [$\\mu erg\\ cm^{-2}\\ s^{-1}\\ sr^{-1}\\ Hz^{-1}]$'], 'T [kK]', '$v_{LOS}~[km/s]$', '$v_{turb}~[km/s]$', '$n_e~[cm^{-3}]$', ['IRL $[kW~m^{-2}]$', '$\\chi^{2}$']]
# [[407.78443880832225, 522.7226788325049, 285.6942, 414.7818], [407.78443880832225, 522.7226788325049, 285.6942, 414.7818], [407.78443880832225, 522.7226788325049, 285.6942, 414.7818], [407.78443880832225, 522.7226788325049, 285.6942, 414.7818], [407.78443880832225, 522.7226788325049, 285.6942, 414.7818], [407.78443880832225, 522.7226788325049, 285.6942, 414.7818]]
# ...

# %%
[[50, 112, 1334.55, 266.5789797505271], 
[140, 202, 1335.72, 205.9139114097768],
 [244, 252, 2793.22, 200739.87278740783], 
 [313, 391, 2796.35, 1.0],
  [441, 456, 2798.8, 3.156031923525305],
   [595, 673, 2803.53, 1.2486599572960402], 
   [743, 751, 2815.18, 0.6120405488125195]]
